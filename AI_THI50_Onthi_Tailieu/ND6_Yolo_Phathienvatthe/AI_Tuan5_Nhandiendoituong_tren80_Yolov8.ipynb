# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/AI_1333/AI_Tuan5
# !rm -rf ultralytics
# !git clone https://github.com/ultralytics/ultralytics.git
# %cd ultralytics
# !wget https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt
# %pip install -qr requirements.txt
import cv2
# !pip install ultralytics
from google.colab.patches import cv2_imshow
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/AI_1333/AI_Tuan5'
# /content
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 5784, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 5784 (delta 8), reused 8 (delta 4), pack-reused 5753
# Receiving objects: 100% (5784/5784), 4.53 MiB | 8.76 MiB/s, done.
# Resolving deltas: 100% (3905/3905), done.
# /content/ultralytics
# --2023-03-08 02:39:31--  https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# https://docs.ultralytics.com/cfg/

# %%
# hide_labels=True hide_conf=True
# conf=0.8 >= 80
#!yolo predict model=yolov8s.pt conf=0.8 save=True source=/content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/ND5_resources/Hinh1.png
# !yolo predict model=yolov8s.pt conf=0.8 iou=0.4 save=True source=/content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/ND5_resources/Hinh1.png
# Out:
# Ultralytics YOLOv8.0.48 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/ND5_resources/Hinh1.png: 448x640 2 persons, 1 car, 2 motorcycles, 384.9ms
# Speed: 2.0ms preprocess, 384.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict7

# %%
img = cv2.imread('/content/drive/MyDrive/AI_1333/AI_Tuan5/ultralytics/runs/detect/predict7/Hinh1.png')
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
