# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/AI_1333/AI_Tuan5
# Out:
# /content/drive/MyDrive/AI_1333/AI_Tuan5

# %%
# !pwd
# Out:
# /content/drive/MyDrive/AI_1333/AI_Tuan5/Yolov5

# %% [markdown]
# https://github.com/ultralytics/yolov5

# %%
# %cd /content/drive/MyDrive/AI_1333/AI_Tuan5
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install import tất cả file và thư viện

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-116-g5c91dae Python-3.8.10 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.8/107.7 GB disk)

# %% [markdown]
# def run(
# * weights=ROOT / 'yolov5s.pt',  # model path or triton URL
# * source=ROOT / 'data/images',  # file/dir/URL/glob/screen/0(webcam)
# * data=ROOT / 'data/coco128.yaml',  # dataset.yaml path
# * imgsz=(640, 640),  # inference size (height, width)
# * conf_thres=0.25,  # confidence threshold
# * iou_thres=0.45,  # NMS IOU threshold
# * max_det=1000,  # maximum detections per image
# * device='',  # cuda device, i.e. 0 or 0,1,2,3 or cpu
# * view_img=False,  # show results
# * save_txt=False,  # save results to *.txt
# * save_conf=False,  # save confidences in --save-txt labels
# * save_crop=False,  # save cropped prediction boxes
# * nosave=False,  # do not save images/videos
# * classes=None,  # filter by class: --class 0, or --class 0 2 3
# * agnostic_nms=False,  # class-agnostic NMS
# * augment=False,  # augmented inference
# * visualize=False,  # visualize features
# * update=False,  # update all models
# * project=ROOT / 'runs/detect',  # save results to project/name
# * name='exp',  # save results to project/name
# * exist_ok=False,  # existing project/name ok, do not increment
# * line_thickness=3,  # bounding box thickness (pixels)
# * hide_labels=False,  # hide labels
# * hide_conf=False,  # hide confidences
# * half=False,  # use FP16 half-precision inference
# * dnn=False,  # use OpenCV DNN for ONNX inference
# * vid_stride=1,  # video frame-rate stride
# ):
#
#
# ---
#
#
# * weights: đường dẫn đến trọng số của mô hình YOLOv5
# * source: đường dẫn đến tệp ảnh hoặc video hoặc webcam
# * data: đường dẫn đến tệp dữ liệu của tập dữ liệu COCO
# * imgsz: kích thước ảnh đầu vào cho quá trình suy luận
# * **conf_thres**: ngưỡng tin cậy để phát hiện đối tượng # THI!!! | Chỉnh định: chỉ định ngưỡng **tối thiểu**
# * **iou_thres**: ngưỡng chồng chéo giữa các hộp giới hạn để áp dụng thuật toán NMS | Chỉnh định: chỉ định ngưỡng **tối đa**
# * max_det: số lượng đối tượng tối đa được phát hiện trên mỗi ảnh
# * device: thiết bị sử dụng cho quá trình suy luận, có thể là GPU hoặc CPU
# * view_img: hiển thị kết quả trên ảnh
# * save_txt: lưu kết quả dưới dạng file văn bản
# * save_conf: lưu giá trị độ tin cậy của các đối tượng được phát hiện
# * save_crop: lưu hình ảnh đã được cắt để phát hiện đối tượng
# * nosave: không lưu ảnh hoặc video
# * classes: chỉ phát hiện các lớp cụ thể, có thể chỉ định số hoặc tên lớp
# * agnostic_nms: áp dụng thuật toán NMS không phụ thuộc vào lớp
# * augment: sử dụng kỹ thuật tăng cường dữ liệu để phát hiện đối tượng
# * visualize: hiển thị kết quả trên đối tượng
# * update: cập nhật tất cả các mô hình
# * project: đường dẫn đến thư mục để lưu kết quả
# * name: tên thư mục để lưu kết quả
# * exist_ok: cho phép ghi đè kết quả cũ nếu đã tồn tại
# * line_thickness: độ dày của đường viền cho hộp giới hạn
# * hide_labels: không hiển thị nhãn của đối tượng
# * hide_conf: không hiển thị giá trị độ tin cậy của đối tượng
# * half: sử dụng kiểu dữ liệu độ chính xác nửa (FP16) để phát hiện đối tượng
# * dnn: sử dụng thư viện OpenCV DNN cho quá trình suy luận
# * vid_stride là số lượng khung hình của video sẽ được bỏ qua trước khi thực hiện phát hiện đối tượng. Ví dụ: nếu vid_stride=2, mỗi khung hình thứ 2 sẽ được bỏ qua để giảm độ phức tạp tính toán.

# %%
# !python detect.py --source /content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg
# Out:
# detect: weights=yolov5s.pt, source=/content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-116-g5c91dae Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg: 480x640 1 person, 1 chair, 6 tvs, 2 mouses, 1 keyboard, 355.6ms
# Speed: 2.8ms pre-process, 355.6ms inference, 20.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
display.Image(filename='/content/drive/MyDrive/AI_1333/AI_Tuan5/yolov5/runs/detect/exp3/img_test3.jpg', width=600)

# %%
# Độ chính xác nhận diện 25%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg # weights: file mô hình đã huấn luyện sẵn / 640 kích cỡ tấm hình / conf: Độ chính xác khi nhận diện 25% (đề 95% -> 0.95) / [đọc thư mục]
# Chỉnh ở file detect.py : chỉnh độ chính xác
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-116-g5c91dae Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg: 480x640 1 person, 1 chair, 6 tvs, 2 mouses, 1 keyboard, 321.7ms
# Speed: 2.7ms pre-process, 321.7ms inference, 3.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
display.Image(filename='runs/detect/exp4/img_test3.jpg', width=600)

# %%
# !python detect.py --conf-thres 0.8 --view-img --source /content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg
# !python detect.py --conf-thres 0.7 --source /content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg
# Out:
# detect: weights=yolov5s.pt, source=/content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.8, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-116-g5c91dae Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/AI_Tailieu/ND5_Yolo_Phathienvatthe/img_test3.jpg: 480x640 2 tvs, 329.3ms
# Speed: 2.7ms pre-process, 329.3ms inference, 7.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp10

# %%
display.Image(filename='runs/detect/exp10/img_test3.jpg', width=600)
