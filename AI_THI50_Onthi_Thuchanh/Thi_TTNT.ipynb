# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/MyDrive/TTNT/tiger.jpg')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
rows,cols = img.shape[:2]
cv2_imshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

# %%
kerrel_identity = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
output=cv2.filter2D(img,-1,kerrel_identity)
cv2_imshow(output)

# %%
Egde_detection_kernel = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
output=cv2.filter2D(gray,-1,Egde_detection_kernel)
cv2_imshow(output)

# %% [markdown]
# Cau 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors, datasets
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
print ('Number of classes: %d' %len(np.unique(iris_y)))
print ('Number of data points: %d' %len(iris_y))
X0 = iris_X[iris_y == 0,:]
print ('\nSamples from class 0:\n', X0[:5,:])
X1 = iris_X[iris_y == 1,:]
print ('\nSamples from class 1:\n', X1[:5,:])
X2 = iris_X[iris_y == 2,:]
print ('\nSamples from class 2:\n', X2[:5,:])
X3 = iris_X[iris_y == 2,:]
print ('\nSamples from class 2:\n', X3[:5,:])
X4 = iris_X[iris_y == 2,:]
print ('\nSamples from class 2:\n', X4[:5,:])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
 iris_X, iris_y, test_size=30)
print ("Training size: %d" %len(y_train))
print ("Test size : %d" %len(y_test))

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors = 10, p = 2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print ("Print results for 20 test data points:")
print ("Predicted labels: ", y_pred[20:40])
print ("Ground truth : ", y_test[20:40])

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy of 1NN: %.2f %%" %(100*accuracy_score(y_test, y_pred)))

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors = 10, p = 2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print ("Accuracy of 10NN with major voting: %.2f %%" %(100*accuracy_score(y_test, y_pred)))

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors = 10, p = 2, weights = 'distance')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print ("Accuracy of 10NN (1/distance weights): %.2f %%" %(100*accuracy_score(y_test, y_pred)))

# %%
def myweight(distances):
 sigma2 = .5 # we can change this number
 return np.exp(-distances**2/sigma2)
clf = neighbors.KNeighborsClassifier(n_neighbors = 10, p = 2, weights = myweight)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print ("Accuracy of 10NN (customized weights): %.2f %%" %(100*accuracy_score(y_test, y_pred)))

# %% [markdown]
# Cau 3

# %%
import cv2
import numpy as np
from skimage.feature import hog
#from sklearn.svm import LinearSVC
#from sklearn.svm import SVC
from sklearn.svm import SVC
svc = SVC()
from keras.datasets import mnist
from sklearn.metrics import accuracy_score
from google.colab.patches import cv2_imshow

# %%
(X_train,y_train),(X_test,y_test) = mnist.load_data()
 
X_train_feature = []
for i in range(len(X_train)):
    feature = hog(X_train[i],orientations=9,pixels_per_cell=(14,14),cells_per_block=(1,1),block_norm="L2")
    X_train_feature.append(feature)
X_train_feature = np.array(X_train_feature,dtype = np.float32)
 
#cho x_test
X_test_feature = []
for i in range(len(X_test)):
    feature = hog(X_test[i],orientations=9,pixels_per_cell=(14,14),cells_per_block=(1,1),block_norm="L2")
    X_test_feature.append(feature)
X_test_feature = np.array(X_test_feature,dtype=np.float32)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
model = SVC(C=10, probability=True)
model.fit(X_train_feature,y_train)
y_pre = model.predict(X_test_feature)
print(accuracy_score(y_test,y_pre))

# %% [markdown]
# - Đoạn mã này sử dụng thuật toán Support Vector Machine (SVM) để huấn luyện một mô hình phân loại.
#
# - Cụ thể, mô hình được xác định bằng cách sử dụng lớp SVC của SVM từ thư viện scikit-learn trong Python. Tham số C được thiết lập là 10, điều này cho phép điều chỉnh giữa độ chính xác của mô hình và bộ phân loại siêu phẳng.
#
# - Tham số probability cũng được thiết lập thành True, cho phép mô hình tính toán xác suất dự đoán của nó.
#
# - Dữ liệu huấn luyện được đưa vào mô hình bằng cách sử dụng phương thức fit. X_train_feature là một mảng 2D chứa các đặc trưng của dữ liệu huấn luyện và y_train là một mảng 1D chứa các nhãn phân loại tương ứng.
#
# - Sau khi huấn luyện xong, mô hình được sử dụng để dự đoán các nhãn phân loại của dữ liệu kiểm tra X_test_feature bằng phương thức predict.
#
# - Cuối cùng, độ chính xác của mô hình được tính toán bằng phương thức accuracy_score từ thư viện scikit-learn và được in ra màn hình.

# %%
model = SVC(C=10, probability=True)
model.fit(X_train_feature,y_train)
y_pre = model.predict(X_test_feature)
print(accuracy_score(y_test,y_pre))

image = cv2.imread("/content/drive/MyDrive/AI_1333/AI_Tuan2/Tuan2_BatoanDulieuMNIST/test_img.jpg")
im_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
im_blur = cv2.GaussianBlur(im_gray,(5,5),0)
im,thre = cv2.threshold(im_blur,90,255,cv2.THRESH_BINARY_INV)
contours,hierachy = cv2.findContours(thre,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.boundingRect(cnt) for cnt in contours]
for i in contours:
    (x,y,w,h) = cv2.boundingRect(i)
   
    roi = thre[y:y+h,x:x+w]
    roi = np.pad(roi,(20,20),'constant',constant_values=(0,0))
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    roi = cv2.dilate(roi, (3, 3))
    
    # Calculate the HOG features
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1),block_norm="L2")
    nbr = model.predict(np.array([roi_hog_fd], np.float32))
    per = model.predict_proba(np.array([roi_hog_fd], np.float32))[0]
    per = float(str(round(per[nbr][0]*100,1)));
    print(per)

    if 80 < per:
      cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),3)
      cv2.putText(image, str(int(nbr[0])), (x, y),cv2.FONT_HERSHEY_DUPLEX, 2, (0, 255, 255), 3)
      cv2_imshow(image)
    else:
      cv2_imshow(image)
      print('ti le nhan dang thap hon 80')


cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# - Đoạn mã này sử dụng thư viện OpenCV trong Python để xác định chữ số trong ảnh được cung cấp và dự đoán giá trị của chúng bằng một mô hình đã được huấn luyện.
#
# - Đầu tiên, ảnh được đọc vào chương trình bằng phương thức cv2.imread và chuyển sang ảnh xám bằng phương thức cv2.cvtColor. Sau đó, ảnh được làm mờ bằng phương thức cv2.GaussianBlur và đưa vào phương thức cv2.threshold để chuyển đổi sang dạng nhị phân.
#
# - Sau đó, các đường viền được tìm thấy bằng phương thức cv2.findContours và các hình chữ nhật được bao quanh các đối tượng bằng phương thức cv2.boundingRect.
#
# - Với mỗi hình chữ nhật, vùng chứa số được cắt ra từ ảnh và được thêm viền bằng phương thức np.pad. Sau đó, ảnh được thay đổi kích thước thành 28x28 bằng phương thức cv2.resize và được phóng to bằng phương thức cv2.dilate.
#
# - Sau đó, tính toán các đặc trưng HOG của ảnh bằng phương thức hog và sử dụng mô hình đã huấn luyện để dự đoán giá trị của số bằng phương thức model.predict và xác suất của dự đoán bằng phương thức model.predict_proba. Độ chính xác của dự đoán được tính toán và in ra màn hình.
#
# - Nếu độ chính xác của dự đoán là hơn 80%, một hình chữ nhật và số được vẽ lên ảnh và hiển thị ra màn hình bằng phương thức cv2.rectangle, cv2.putText và cv2.imshow. Nếu độ chính xác của dự đoán là thấp hơn 80%, một thông báo được in ra màn hình để thông báo về việc xác định số không thành công.
#
# - Phương thức cv2.waitKey và cv2.destroyAllWindows được sử dụng để giữ cửa sổ hiển thị ảnh mở đến khi người dùng nhấn phím bất kỳ.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import hog
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

IMAGE_PATH = "/content/drive/MyDrive/AI_1333/AI_Tuan2/Tuan2_BatoanDulieuMNIST/test_img.jpg"
THRESHOLD = 90
MIN_ACCURACY = 80

def load_image(image_path):
    image = cv2.imread(image_path)
    im_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    im_blur = cv2.GaussianBlur(im_gray, (5,5), 0)
    _, thre = cv2.threshold(im_blur, THRESHOLD, 255, cv2.THRESH_BINARY_INV)
    contours, _ = cv2.findContours(thre, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    return image, contours

def process_digit(contour, image):
    (x, y, w, h) = cv2.boundingRect(contour)
    roi = thre[y:y+h, x:x+w]
    roi = np.pad(roi, (20,20), 'constant', constant_values=(0,0))
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    roi = cv2.dilate(roi, (3, 3))
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), block_norm="L2")
    return roi_hog_fd

def predict_digit(model, roi_hog_fd):
    nbr = model.predict(np.array([roi_hog_fd], np.float32))
    per = model.predict_proba(np.array([roi_hog_fd], np.float32))[0]
    per = float(str(round(per[nbr][0]*100, 1)))
    return nbr, per

def draw_digit(image, contour, digit, accuracy):
    if accuracy > MIN_ACCURACY:
        (x, y, w, h) = cv2.boundingRect(contour)
        cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 3)
        cv2.putText(image, str(int(digit[0])), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                                                                                    
rects = [cv2.boundingRect(cnt) for cnt in contours]

for rect in rects:
    (x,y,w,h) = rect
   
    roi = thre[y:y+h,x:x+w]
    roi = np.pad(roi,(20,20),'constant',constant_values=(0,0))
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    roi = cv2.dilate(roi, (3, 3))
    
    # Calculate the HOG features
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1),block_norm="L2")
    nbr = model.predict(np.array([roi_hog_fd], np.float32))
    per = model.predict_proba(np.array([roi_hog_fd], np.float32))[0]
    per = float(str(round(per[nbr][0]*100,1)));
    print(per)

    if 80 < per:
      cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),3)
      # cv2.putText(image, str(int(nbr[0])), (x, y),cv2.FONT_HERSHEY_DUPLEX, 2, (0, 255, 255), 3)
      cv2_imshow(image)
    else:
      cv2_imshow(image)
      print('ti le nhan dang thap hon 80')

cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import hog
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

image = cv2.imread("/content/drive/MyDrive/AI_1333/AI_Tuan2/Tuan2_BatoanDulieuMNIST/test_img.jpg")
im_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
im_blur = cv2.GaussianBlur(im_gray,(5,5),0)
im,thre = cv2.threshold(im_blur,90,255,cv2.THRESH_BINARY_INV)
contours,hierachy = cv2.findContours(thre,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.boundingRect(cnt) for cnt in contours]

for rect in rects:
    (x,y,w,h) = rect
   
    roi = thre[y:y+h,x:x+w]
    roi = np.pad(roi,(20,20),'constant',constant_values=(0,0))
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    roi = cv2.dilate(roi, (3, 3))
    
    # Calculate the HOG features
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1),block_norm="L2")
    nbr = model.predict(np.array([roi_hog_fd], np.float32))
    per = model.predict_proba(np.array([roi_hog_fd], np.float32))[0]
    per = float(str(round(per[nbr][0]*100,1)));
    print(per)

    if 80 < per:
      cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),3)
      cv2.putText(image, str(int(nbr[0])), (x, y),cv2.FONT_HERSHEY_DUPLEX, 2, (0, 255, 255), 3)
      cv2_imshow(image)
    else:
      cv2_imshow(image)
      print('ti le nhan dang thap hon 80')

cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import hog
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

IMAGE_PATH = "/content/drive/MyDrive/AI_1333/AI_Tuan2/Tuan2_BatoanDulieuMNIST/test_img.jpg"
THRESHOLD = 90
MIN_ACCURACY = 80

def load_image(image_path):
    image = cv2.imread(image_path)
    im_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    im_blur = cv2.GaussianBlur(im_gray, (5,5), 0)
    _, thre = cv2.threshold(im_blur, THRESHOLD, 255, cv2.THRESH_BINARY_INV)
    contours, _ = cv2.findContours(thre, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    return image, contours

def process_digit(contour, image):
    (x, y, w, h) = cv2.boundingRect(contour)
    roi = thre[y:y+h, x:x+w]
    roi = np.pad(roi, (20,20), 'constant', constant_values=(0,0))
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    roi = cv2.dilate(roi, (3, 3))
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), block_norm="L2")
    return roi_hog_fd

def predict_digit(model, roi_hog_fd):
    nbr = model.predict(np.array([roi_hog_fd], np.float32))
    per = model.predict_proba(np.array([roi_hog_fd], np.float32))[0]
    per = float(str(round(per[nbr][0]*100, 1)))
    return nbr, per

def draw_digit(image, contour, digit, accuracy):
    if accuracy > MIN_ACCURACY:
        (x, y, w, h) = cv2.boundingRect(contour)
        cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 3)
        cv2.putText(image, str(int(digit[0])), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        
digits = []
accuracies = []
rects = [cv2.boundingRect(cnt) for cnt in contours]
for rect in rects:
    (x,y,w,h) = rect

    roi = thre[y:y+h,x:x+w]
    roi = np.pad(roi,(20,20),'constant',constant_values=(0,0))
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    roi = cv2.dilate(roi, (3, 3))

    # Calculate the HOG features
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1),block_norm="L2")
    nbr, per = predict_digit(model, roi_hog_fd)

    digits.append(nbr[0])
    accuracies.append(per)

    draw_digit(image, contours, nbr, per)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

for i in range(len(digits)):
    print("Digit {}: {}%".format(digits[i], accuracies[i]))

# %%
image = cv2.imread("/content/drive/MyDrive/AI_1333/AI_Tuan2/Tuan2_BatoanDulieuMNIST/test_img.jpg")
im_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
im_blur = cv2.GaussianBlur(im_gray,(5,5),0)
im,thre = cv2.threshold(im_blur,90,255,cv2.THRESH_BINARY_INV)
contours,_ = cv2.findContours(thre,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)

pixels_per_cell = (14, 14)
cells_per_block = (1, 1)
block_norm = "L2"

for cnt in contours:
    (x,y,w,h) = cv2.boundingRect(cnt)
   
    roi = thre[y:y+h,x:x+w]
    roi = np.pad(roi,(20,20),'constant',constant_values=(0,0))
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)
    roi = cv2.dilate(roi, (3, 3))
    
    # Calculate the HOG features
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=pixels_per_cell, cells_per_block=cells_per_block, block_norm=block_norm)
    nbr = model.predict(np.array([roi_hog_fd], np.float32))
    per = model.predict_proba(np.array([roi_hog_fd], np.float32))[0]
    per = float(str(round(per[nbr][0]*100,1)));
    
    if 80 < per:
      cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),3)
      cv2.putText(image, str(int(nbr[0])), (x, y),cv2.FONT_HERSHEY_DUPLEX, 2, (0, 255, 255), 3)
      cv2_imshow(image)
    else:
      cv2_imshow(image)
      print('ti le nhan dang thap hon 80')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import hog
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load trained SVM model
model = SVC(kernel='linear', probability=True, random_state=42)
model.load("/content/drive/MyDrive/AI_1333/AI_Tuan2/Tuan2_BatoanDulieuMNIST/svm_mnist_model.dat")

# Load test image
image = cv2.imread("/content/drive/MyDrive/AI_1333/AI_Tuan2/Tuan2_BatoanDulieuMNIST/test_img.jpg", cv2.IMREAD_GRAYSCALE)

# Threshold and find contours
thresh = cv2.threshold(image, 90, 255, cv2.THRESH_BINARY_INV)[1]
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Iterate over contours
for i, contour in enumerate(contours):
    x, y, w, h = cv2.boundingRect(contour)
    roi = thresh[y:y+h, x:x+w]

    # Pad and resize ROI
    roi = np.pad(roi, (20, 20), 'constant', constant_values=(0, 0))
    roi = cv2.resize(roi, (28, 28), interpolation=cv2.INTER_AREA)

    # Dilate ROI
    roi = cv2.dilate(roi, (3, 3))

    # Calculate HOG features
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), block_norm="L2")

    # Predict label and probability
    nbr = model.predict(np.array([roi_hog_fd], np.float32))
    per = model.predict_proba(np.array([roi_hog_fd], np.float32))[0][nbr][0] * 100

    # Draw rectangle and label
    if per > 80:
        cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 3)
        cv2.putText(image, str(int(nbr[0])), (x, y), cv2.FONT_HERSHEY_DUPLEX, 2, (0, 255, 255), 3)
    else:
        print('Tỉ lệ nhận dạng thấp hơn 80')
