# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets as datas
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing

# %%
dataset = pd.read_csv('/content/drive/MyDrive/HK3_P/AI/AI_Baitap_Tuan2/PlayTennis.csv')

# X=df.iloc[:, 1:]
# print(X.head(8))
# Y=df.iloc[:, -1]
# print(Y.head(0))
# df = pd.DataFrame(df)
le = preprocessing.LabelEncoder()
dataset =dataset.apply(le.fit_transform)
dataset=dataset.iloc[1:, 1:]
dataset.head(10)
# Out:
#     Outlook  Temprature  Humidity  Wind  Play_Tennis
# 1         2           1         0     0            0
# 2         0           1         0     1            1
# 3         1           2         0     1            1
# 4         1           0         1     1            1
# 5         1           0         1     0            0
# 6         0           0         1     0            1
# 7         2           2         0     1            0
# 8         2           0         1     1            1
# 9         1           2         1     1            1
# 10        2           2         1     0            1

# %%
dataset.columns
# Out:
# Index(['Outlook', 'Temprature', 'Humidity', 'Wind', 'Play_Tennis'], dtype='object')

# %%
atribut = ['outlook', 'temp', 'humidity', 'wind']

# %%
data = dataset.loc[:, :]
target = dataset["Play_Tennis"]

# %%
target
# Out:
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: Play_Tennis, dtype: int64

# %%
df.shape # Coi bao nhiêu hàng và cột (Hàng, cột)

# %%
df.isnull()

# %%
df.info()

# %%
df.describe()

# %%
df.Outlook
# Out:
# 0        Sunny
# 1        Sunny
# 2     Overcast
# 3         Rain
# 4         Rain
# 5         Rain
# 6     Overcast
# 7        Sunny
# 8        Sunny
# 9         Rain
# 10       Sunny
# 11    Overcast
# 12    Overcast
# 13        Rain
# Name: Outlook, dtype: object

# %%
df.columns
# Out:
# Index(['Day', 'Outlook', 'Temprature', 'Humidity', 'Wind', 'Play_Tennis'], dtype='object')

# %%
df.target
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-19f665f653ea> in <module>
# ----> 1 df.target
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %% [markdown]
# Assign value to input by which we predict value of Y

# %%
X=df.iloc[:, 1:]
print(X.head(14))
Y=df.iloc[:, -1]
print(Y.head(1))

# %%
irisdata = datas.load_iris()

# %% [markdown]
# # ***TRAINING DATA***

# %%
X_train, X_test, Y_train, Y_test = train_test_split(dataset, target, test_size=0.2)
print("X_train is\n", X_train.shape)
print("X_test is\n", X_test.shape)
print("Y_train is\n", Y_train.shape)
print("Y_test is", Y_test.shape)
# Out:
# X_train is
#  (10, 5)
# X_test is
#  (3, 5)
# Y_train is
#  (10,)
# Y_test is (3,)

# %% [markdown]
# # ***DECISION TREE IMPLEMENTATION***

# %%
# Classifier.fit(X_train, Y_train)

#Decision tree formation on begalf of entropy or you can dono it by using gino criteia also

# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy', max_depth=None, max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1, min_samples_split=2,min_weight_fraction_leaf=0.0, presort='deprecated', random_state=None, splitter='best')

# %%
# Buil model
modl = tree.DecisionTreeClassifier(criterion='entropy')
modl.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
modl.fit(X_train, Y_train)
fig, ax = plt.subplots(figsize=(10, 10))
tree.plot_tree(modl, ax=ax, feature_names=atribut, filled=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-200-a4cb0567600f> in <module>
#       1 modl.fit(X_train, Y_train)
#       2 fig, ax = plt.subplots(figsize=(10, 10))
# ----> 3 tree.plot_tree(modl, ax=ax, feature_names=atribut, filled=True)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     193         fontsize=fontsize,
#     194     )
# --> 195     return exporter.export(decision_tree, ax=ax)
#     196
#     197
#
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_export.py in export(self, decision_tree, ax)
#     654         ax.clear()
#     655         ax.set_axis_off()
# --> 656         my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
# ...

# %%
predictedData = modl.predict(X_test)
predictedData

# %%
#import tree from sklearn for plotting
from sklearn import tree
feat=["Outlook","Temprature","Humidity","Wind"]
Cls=[]
fig, axes=plt.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=300)
tree.plot_tree(df, feature_names=predictedData, class_names=Cls, filled=True)
