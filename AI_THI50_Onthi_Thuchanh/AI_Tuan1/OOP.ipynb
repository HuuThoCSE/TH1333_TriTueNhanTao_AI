# %% [markdown]
# Ví dụ: Viết chương trình tính tổng các số nguyên lẻ đầu tiên cho đến khi tổng này vừa lớn hơn giá trị M, với M được nhập từ bàn phím.

# %%
M = int(input("Nhap gia tri M = "))
S, i = 0, 1
while S <= M:
  S += i 
  i +=2
print("Tong vua lon hon",M,"la:",S)

# %%
# %pwd
# Out:
# '/content'

# %%
class Car:
  # thuộc tính lớp
  loaixe = "Ô tô"
  # thuộc tính đối tượng
  def __init__(self, tenxe, mausac, nguyenlieu):
    self.tenxe = tenxe
    self.mausac = mausac
    self.nguyenlieu = nguyenlieu

  def dungxe(self, mucdich):
      return self.tenxe + "đang dừng xe để "+ mucdich
  
  def chayxe(self):
      return self.tenxe + "đang chạy trên đường"

  def nomay(self):
      return self.tenxe + "đang nổ  máy"

  class Toyota(Car):
    # Gọi tới constructor cuar lớ cha (Car)
    # để gán giá trị vào thuộc tính của lớp cha
    def __init__(self, hangxe, tenxe, mausac, nguyenlieu):
      super().__init__(hangxe, tenxe, mausac)
      self.nguyenlieu = nguyenlieu

    # Ke thua phuong thuc cũ 

# Tạo các đối tượng thuộc lớp Car
toyota = Car("Toyota", "Đỏ", "Điện")
lamborghini = Car("Lamborghini", "Vàng", "Deisel")
porsche = Car("Porsche", "Xanh", "Gas")

#Truy xuất thuoc tinh lop
print("Porsche là ",porsche.__class__.loaixe)
print("Toyota là ", toyota.__class__.loaixe)
print("Laborghini cũng là ", lamborghini.__class__.loaixe)

#Truy xuat thuoc tinh doi tuong
print()
print("Xe", toyota.tenxe, "co mau", toyota.mausac, 
      "va co nguyen lieu van hanh la", toyota.nguyenlieu,".")
print("Xe", lamborghini.tenxe, "co mau", lamborghini.mausac, 
      "va co nguyen lieu van hanh la", lamborghini.nguyenlieu,".")
print("Xe", porsche.tenxe, "co mau", porsche.mausac, 
      "va co nguyen lieu van hanh la", porsche.nguyenlieu,".")

#Gọi các phương thức của các đối tượng
print("")
print(toyota.dungxe("nạp điện"))
print(lamborghini.chayxe())
print(porsche.nomay())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a6ae119be85c> in <module>
# ----> 1 class Car:
#       2   # thuộc tính lớp
#       3   loaixe = "Ô tô"
#       4   # thuộc tính đối tượng
#       5   def __init__(self, tenxe, mausac, nguyenlieu):
#
# <ipython-input-2-a6ae119be85c> in Car()
#      17       return self.tenxe + "đang nổ  máy"
#      18
# ---> 19   class Toyota(Car):
#      20     # Gọi tới constructor cuar lớ cha (Car)
#      21     # để gán giá trị vào thuộc tính của lớp cha
#
# NameError: name 'Car' is not defined
